# %%
# %pip list
# Out:
# Package                               Version
# ------------------------------------- ------------
# aiohttp                               3.8.1
# aiosignal                             1.2.0
# ansiwrap                              0.8.4
# anyio                                 3.4.0
# appdirs                               1.4.4
# argcomplete                           1.12.3
# argon2-cffi                           21.1.0
# arrow                                 1.2.1
# asn1crypto                            1.4.0
# async-generator                       1.10
# async-timeout                         4.0.1
# asynctest                             0.13.0
# attrs                                 21.2.0
# Babel                                 2.9.1
# backcall                              0.2.0
# backports.functools-lru-cache         1.6.4
# beatrix-jupyterlab                    3.1.4
# binaryornot                           0.4.4
# black                                 21.11b1
# ...

# %%
import pandas as pd

# %%
import xgboost
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_27941/2457254733.py in <module>
# ----> 1 import xgboost
#
# ModuleNotFoundError: No module named 'xgboost'

# %%
# %pip install xgboost
# Out:
# ...
#      |████████████████████████████████| 173.5 MB 9.3 kB/s
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import xgboost

# %%
# %%bigquery
# SELECT * FROM `bigquery-public-data.san_francisco_trees.street_trees` LIMIT 1000
# Out:
# ...
# Downloading: 100%|██████████| 1000/1000 [00:01<00:00, 668.58rows/s]
#      tree_id    legal_status                                    species  \
# 0      44866  Permitted Site                                 Tree(s) ::
# 1      34921  Permitted Site                                 Tree(s) ::
# 2      45916  Permitted Site                                 Tree(s) ::
# 3      97355  Permitted Site                                 Tree(s) ::
# 4      33929  Permitted Site                                 Tree(s) ::
# ..       ...             ...                                        ...
# 995    36611  Permitted Site                Robinia x ambigua :: Locust
# 996    36623  Permitted Site  Magnolia grandiflora :: Southern Magnolia
# 997    36635  Permitted Site  Magnolia grandiflora :: Southern Magnolia
# 998    44546  Permitted Site                                 Tree(s) ::
# 999    44695  Permitted Site                                 Tree(s) ::
#
# ...

# %%
# %%bigquery df_tree
# SELECT species, count(*) as num_tree, min(plant_date) as min_plant_date
# FROM `bigquery-public-data.san_francisco_trees.street_trees`
# group by species
# Out:
# ...
# Downloading: 100%|██████████| 576/576 [00:02<00:00, 243.66rows/s]

# %%
df_tree
# Out:
#                                                species  num_tree  \
# 0                                           Tree(s) ::     11776
# 1            Magnolia grandiflora :: Southern Magnolia      6385
# 2       Platanus x hispanica :: Sycamore: London Plane     11692
# 3           Arbutus 'Marina' :: Hybrid Strawberry Tree      5741
# 4                     Ginkgo biloba :: Maidenhair Tree      3258
# ..                                                 ...       ...
# 571                 Rhopalostylis sapida :: Nikau palm         1
# 572  Viburnum odoratissimum var. awabuki :: Sweet v...         6
# 573  Callistemon salignus :: White flowering bottle...         1
# 574                 Macadamia tetraphylla :: Macadamia         1
# 575                  Corylus colurna :: Hazel: Turkish         2
#
#                min_plant_date
# 0   1955-09-19 12:00:00+00:00
# 1   1955-12-13 12:00:00+00:00
# 2   1956-02-15 12:00:00+00:00
# 3   1956-02-06 12:00:00+00:00
# ...
